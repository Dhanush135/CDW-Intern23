# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Brain_stroke_prediction.csv')

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df.head(15)
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#       gender    age  hypertension  heart_disease ever_married work_type  \
# 4971    Male  37.00             0              0          Yes   Private
# 4972    Male  72.00             0              1          Yes   Private
# 4973    Male   1.32             0              0           No  children
# 4974    Male  58.00             0              0          Yes  Govt_job
# 4975    Male  31.00             0              0           No   Private
# 4976    Male  41.00             0              0           No   Private
# 4977    Male  40.00             0              0          Yes   Private
# 4978  Female  45.00             1              0          Yes  Govt_job
# 4979    Male  40.00             0              0          Yes   Private
# 4980  Female  80.00             1              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 4971          Rural             107.06  29.7           smokes       0
# ...

# %%
df.isnull()
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 0      False  False         False          False         False      False
# 1      False  False         False          False         False      False
# 2      False  False         False          False         False      False
# 3      False  False         False          False         False      False
# 4      False  False         False          False         False      False
# ...      ...    ...           ...            ...           ...        ...
# 4976   False  False         False          False         False      False
# 4977   False  False         False          False         False      False
# 4978   False  False         False          False         False      False
# 4979   False  False         False          False         False      False
# 4980   False  False         False          False         False      False
#
#       Residence_type  avg_glucose_level    bmi  smoking_status  stroke
# ...

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  5
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
mean_value = df['age'].mean()
df['age'].fillna(value = mean_value, inplace = True)

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
X = df['age']
Y = df['heart_disease']

# %%
plt.bar(X,Y)
# Out:
# <BarContainer object of 4981 artists>

# %%
p = df['hypertension'].value_counts()
plt.pie(p, labels=p.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f77ec4b32b0>,
# ...
#  [Text(-1.050181054845504, 0.3272915398289193, '0'),
#   Text(1.0501810625063148, -0.3272915152476579, '1')],
#  [Text(-0.5728260299157293, 0.17852265808850143, '90.4%'),
#   Text(0.5728260340943535, -0.1785226446805407, '9.6%')])

# %%
plt.scatter(X,Y)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df['age'] = scaler.fit_transform(df['age'])

# %%
age_array = df['age'].values.reshape(-1, 1)
normalized_age = scaler.fit_transform(age_array)
df['age'] = normalized_age

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
age_array = df['avg_glucose_level'].values.reshape(-1, 1)
normalized_age = scaler.fit_transform(age_array)
df['avg_glucose_level'] = normalized_age

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban           0.801265  36.6  formerly smoked
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler1 = StandardScaler()

# %%
bmi_array = df['bmi'].values.reshape(-1, 1)
normalized_bmi = scaler1.fit_transform(age_array)
df['bmi'] = normalized_bmi

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  0.816895             0              1          Yes
# 1       Male  0.975586             0              1          Yes
# 2     Female  0.597168             0              0          Yes
# 3     Female  0.963379             1              0          Yes
# 4       Male  0.987793             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male  0.499512             0              0           No
# 4977    Male  0.487305             0              0          Yes
# 4978  Female  0.548340             1              0          Yes
# 4979    Male  0.487305             0              0          Yes
# 4980  Female  0.975586             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level       bmi  \
# 0           Private          Urban           0.801265  2.723411
# ...

# %%
age_array = df['age'].values.reshape(-1, 1)
normalized_age = scaler1.fit_transform(age_array)
df['age'] = normalized_age

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  \
# 0       Male  1.042454             0              1          Yes
# 1       Male  1.616546             0              1          Yes
# 2     Female  0.247559             0              0          Yes
# 3     Female  1.572385             1              0          Yes
# 4       Male  1.660706             0              0          Yes
# ...      ...       ...           ...            ...          ...
# 4976    Male -0.105728             0              0           No
# 4977    Male -0.149889             0              0          Yes
# 4978  Female  0.070915             1              0          Yes
# 4979    Male -0.149889             0              0          Yes
# 4980  Female  1.616546             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level       bmi  \
# 0           Private          Urban           0.801265  2.723411
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
columns_to_encode = ['gender', 'work_type']
df[columns_to_encode] = df[columns_to_encode].apply(encoder.fit_transform)

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  work_type  \
# 0          1  1.042454             0              1          Yes          1
# 1          1  1.616546             0              1          Yes          1
# 2          0  0.247559             0              0          Yes          1
# 3          0  1.572385             1              0          Yes          2
# 4          1  1.660706             0              0          Yes          1
# ...      ...       ...           ...            ...          ...        ...
# 4976       1 -0.105728             0              0           No          1
# 4977       1 -0.149889             0              0          Yes          1
# 4978       0  0.070915             1              0          Yes          0
# 4979       1 -0.149889             0              0          Yes          1
# 4980       0  1.616546             1              0          Yes          1
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# %%
df[['smoking_status']] = encoder.fit_transform(df[['smoking_status']])

# %%
df
# Out:
#       gender       age  hypertension  heart_disease ever_married  work_type  \
# 0          1  1.042454             0              1          Yes          1
# 1          1  1.616546             0              1          Yes          1
# 2          0  0.247559             0              0          Yes          1
# 3          0  1.572385             1              0          Yes          2
# 4          1  1.660706             0              0          Yes          1
# ...      ...       ...           ...            ...          ...        ...
# 4976       1 -0.105728             0              0           No          1
# 4977       1 -0.149889             0              0          Yes          1
# 4978       0  0.070915             1              0          Yes          0
# 4979       1 -0.149889             0              0          Yes          1
# 4980       0  1.616546             1              0          Yes          1
#
# ...
